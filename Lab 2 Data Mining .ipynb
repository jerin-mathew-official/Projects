# %% [markdown]
# # Lab Assignment 2
#
# ## Jerin Mathew
#
# ## Roll No : 2139455

# %% [markdown]
# ### Applying Data Reduction

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("C:/ClassesMSC/GOI1.csv")

df.head()
# Out:
#   Category             States  Literacy Rate (Persons) - Total - 2001  \
# 0    State     Andhra Pradesh                                    60.5
# 1    State  Arunachal Pradesh                                    54.3
# 2    State              Assam                                    63.3
# 3    State              Bihar                                    47.0
# 4    State       Chhattisgarh                                    64.7
#
#    Literacy Rate (Persons) - Total - 2011  \
# 0                                    67.0
# 1                                    65.4
# 2                                    72.2
# 3                                    61.8
# 4                                    70.3
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 0                                    54.5
# 1                                    47.8
# 2                                    59.7
# 3                                    43.9
# 4                                    60.5
#
# ...

# %%
scaling  = StandardScaler()
sdf = scaling.fit_transform(df[['Literacy Rate (Persons) - Total - 2001','Literacy Rate (Persons) - Total - 2011','Literacy Rate (Persons) - Rural - 2001','Literacy Rate (Persons) - Rural - 2011','Literacy Rate (Persons) - Urban - 2001','Literacy Rate (Persons) - Urban - 2011']])
sdf
# Out:
# array([[-0.69561109, -1.09713015, -0.77216782, -1.32459892, -0.9512588 ,
#         -1.06252883],
#        [-1.32390498, -1.29460476, -1.41059304, -1.38262265, -0.57539259,
#         -0.53362559],
#        [-0.41186546, -0.45533766, -0.27667362, -0.29177648,  0.62054535,
#          0.52418089],
#        [-2.06367036, -1.73892263, -1.7822137 , -1.3942274 , -1.66882157,
#         -1.66698968],
#        [-0.26999265, -0.68983876, -0.20044374, -0.67473312, -0.18244155,
#         -0.32584217],
#        [ 1.48314997,  1.58111926,  1.62907332,  1.71584466,  0.4667819 ,
#          0.80752191],
#        [ 0.17589333,  0.2605078 , -0.12421386, -0.01326257,  0.02257638,
#          0.10861406],
#        [ 0.05428807, -0.03570411,  0.0568321 , -0.04807681, -0.42162914,
#         -0.49584679],
#        [ 0.92579249,  0.85293163,  1.19075152,  1.17042157,  1.23559915,
#          1.01530533],
#        [-1.20229971, -1.07244582, -1.22001835, -0.99966602, -1.66882157,
#         -1.62921087],
# ...

# %%
pc = PCA(n_components=2)
pca = pc.fit_transform(sdf)
pca
# Out:
# array([[-2.40998653, -0.1322481 ],
#        [-2.67964076,  0.87051576],
#        [-0.14173239,  1.04563448],
#        [-4.21175512,  0.02610125],
#        [-0.96363984,  0.15677645],
#        [ 3.15900757, -1.0440549 ],
#        [ 0.17767033,  0.02783066],
#        [-0.35284579, -0.54958381],
#        [ 2.60424685,  0.12569448],
#        [-3.167545  , -0.64142049],
#        [-2.67295027,  0.92655419],
#        [-0.40212208,  0.14693893],
#        [ 5.49260852, -0.55998462],
#        [-1.43469143,  0.11928935],
#        [ 1.76675082, -0.15929989],
#        [ 0.25908897, -0.60688558],
#        [ 0.07902086,  1.47322693],
#        [ 4.88174438,  0.70143736],
#        [ 0.83092427,  0.55453807],
#        [-0.58082596,  0.25355983],
#        [-0.20774632, -0.66227488],
#        [-2.40505153, -0.20167617],
#        [ 1.22355498,  0.02001629],
#        [ 0.84839835, -0.23650686],
#        [ 2.82733719,  0.52709999],
#        [-3.18436954, -1.26861454],
#        [ 0.64781327, -0.68240064],
# ...

# %%
ndf = pd.DataFrame(data=pca,columns=['PC1','PC2'])
ndf
# Out:
#          PC1       PC2
# 0  -2.409987 -0.132248
# 1  -2.679641  0.870516
# 2  -0.141732  1.045634
# 3  -4.211755  0.026101
# 4  -0.963640  0.156776
# 5   3.159008 -1.044055
# 6   0.177670  0.027831
# 7  -0.352846 -0.549584
# 8   2.604247  0.125694
# 9  -3.167545 -0.641420
# 10 -2.672950  0.926554
# 11 -0.402122  0.146939
# 12  5.492609 -0.559985
# 13 -1.434691  0.119289
# 14  1.766751 -0.159300
# 15  0.259089 -0.606886
# 16  0.079021  1.473227
# 17  4.881744  0.701437
# 18  0.830924  0.554538
# 19 -0.580826  0.253560
# 20 -0.207746 -0.662275
# 21 -2.405052 -0.201676
# 22  1.223555  0.020016
# 23  0.848398 -0.236507
# 24  2.827337  0.527100
# 25 -3.184370 -1.268615
# 26  0.647813 -0.682401
# 27  0.016736 -0.230264

# %%
ndf.head()
# Out:
#         PC1       PC2
# 0 -2.409987 -0.132248
# 1 -2.679641  0.870516
# 2 -0.141732  1.045634
# 3 -4.211755  0.026101
# 4 -0.963640  0.156776

# %%
plt.bar(ndf["PC1"],ndf["PC2"],ec="black",color="yellow")

plt.ylabel("measure of difference")
plt.xlabel("components")
plt.title("principle component analysis")
plt.show()
